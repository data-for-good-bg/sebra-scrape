# %%
import etl
import pandas as pd

test_files = [
    './Data/SEBRA-09042026.xlsx',
    './Data/SEBRA-15052026.xlsx',
    './Data/SEBRA-27052026.xlsx',
    './Data/SEBRA-28052026.xlsx',
]

# %%
r = etl.parse_sebra_payments_xlsx('./Data/SEBRA-09042026.xlsx')
# Out:
# INFO:etl:Skipping column header row in summary, row=['Код', 'Описание', nan, 'Сума']
# INFO:etl:Skipping descriptive row in summary: I. ПЛАЩАНИЯ ОТ БЮДЖЕТА, ИЗВЪРШЕНИ ЧРЕЗ СЕБРА, ПО ПЪРВОСТЕПЕННИ СИСТЕМИ, row=['I. ПЛАЩАНИЯ ОТ БЮДЖЕТА, ИЗВЪРШЕНИ ЧРЕЗ СЕБРА, ПО ПЪРВОСТЕПЕННИ СИСТЕМИ', nan, nan, nan]
# INFO:etl:Skipping descriptive row between sections: ПЛАЩАНИЯ ОТ БЮДЖЕТА, ИЗВЪРШЕНИ ЧРЕЗ СЕБРА, ПО ПЪРВОСТЕПЕННИ СИСТЕМИ, row=['ПЛАЩАНИЯ ОТ БЮДЖЕТА, ИЗВЪРШЕНИ ЧРЕЗ СЕБРА, ПО ПЪРВОСТЕПЕННИ СИСТЕМИ', nan, nan, nan]
# INFO:etl:Skipping column header row in org section, row=['Код', 'Описание', nan, 'Сума']
# INFO:etl:Skipping column header row in org section, row=['Код', 'Описание', nan, 'Сума']
# INFO:etl:Skipping column header row in org section, row=['Код', 'Описание', nan, 'Сума']
# INFO:etl:Skipping column header row in org section, row=['Код', 'Описание', nan, 'Сума']
# INFO:etl:Skipping column header row in org section, row=['Код', 'Описание', nan, 'Сума']
# ...

# %%
r.summary.data
# Out:
#     start_date    end_date operation_code  \
# 0   09.04.2026  09.04.2026             01
# 1   09.04.2026  09.04.2026             02
# 2   09.04.2026  09.04.2026             03
# 3   09.04.2026  09.04.2026             05
# 4   09.04.2026  09.04.2026             10
# 5   09.04.2026  09.04.2026             18
# 6   09.04.2026  09.04.2026             20
# 7   09.04.2026  09.04.2026             30
# 8   09.04.2026  09.04.2026             40
# 9   09.04.2026  09.04.2026             50
# 10  09.04.2026  09.04.2026             60
# 11  09.04.2026  09.04.2026             88
# 12  09.04.2026  09.04.2026             89
# 13  09.04.2026  09.04.2026             90
# 14  09.04.2026  09.04.2026             91
# 15  09.04.2026  09.04.2026             93
# 16  09.04.2026  09.04.2026             96
# 17  09.04.2026  09.04.2026             98
# 18  09.04.2026  09.04.2026        2974e36
# 19  09.04.2026  09.04.2026        55d283b
# 20  09.04.2026  09.04.2026        d8b5c4b
#
# ...

# %%
from decimal import getcontext, Decimal
import pandas as pd

getcontext().prec = 15

def decimal_sum(s: pd.Series) -> Decimal:
    s = Decimal('0.0')
    for i in amounts:
        s = s + i
    return s


amounts = r.summary.data['amount']
decimal_sum(amounts)
# Out:
# Decimal('179998453.36')

# %%
org_total = Decimal('0')
for o in r.org_sections:
    org_total += o.total_sum

org_total
# Out:
# Decimal('179998453.36')

# %%
def load_excel(f: str) -> pd.DataFrame:
    data = pd.read_excel(f)
    data = data.dropna(how='all')
    return data

# %%
sebra_data = etl.parse_sebra_payments_xlsx(test_files[0])
dir(sebra_data)
# Out:
# INFO:etl:[summary section] Skipping column header row in summary, row=['Код', 'Описание', nan, 'Сума']
# INFO:etl:[summary section] Skipping descriptive row in summary: I. ПЛАЩАНИЯ ОТ БЮДЖЕТА, ИЗВЪРШЕНИ ЧРЕЗ СЕБРА, ПО ПЪРВОСТЕПЕННИ СИСТЕМИ, row=['I. ПЛАЩАНИЯ ОТ БЮДЖЕТА, ИЗВЪРШЕНИ ЧРЕЗ СЕБРА, ПО ПЪРВОСТЕПЕННИ СИСТЕМИ', nan, nan, nan]
# INFO:etl:[org section] Skipping descriptive row between sections: ПЛАЩАНИЯ ОТ БЮДЖЕТА, ИЗВЪРШЕНИ ЧРЕЗ СЕБРА, ПО ПЪРВОСТЕПЕННИ СИСТЕМИ, row=['ПЛАЩАНИЯ ОТ БЮДЖЕТА, ИЗВЪРШЕНИ ЧРЕЗ СЕБРА, ПО ПЪРВОСТЕПЕННИ СИСТЕМИ', nan, nan, nan]
# INFO:etl:[org section] Skipping column header row in org section, row=['Код', 'Описание', nan, 'Сума']
# INFO:etl:[org section] Skipping column header row in org section, row=['Код', 'Описание', nan, 'Сума']
# INFO:etl:[org section] Skipping column header row in org section, row=['Код', 'Описание', nan, 'Сума']
# INFO:etl:[org section] Skipping column header row in org section, row=['Код', 'Описание', nan, 'Сума']
# ...

# %%
import etl
import importlib
importlib.reload(etl)

test_files = [
    './Data/SEBRA-09042026.xlsx',
    './Data/SEBRA-15052026.xlsx',
    './Data/SEBRA-27052026.xlsx',
    './Data/SEBRA-28052026.xlsx',
]

sebra_datas = [
    etl.parse_sebra_payments_xlsx(tf) for tf in test_files
]

test_results = [
    sd.validate_total_sum() for sd in sebra_datas
]

test_results
# Out:
# INFO:etl:Starting parse_sebra_payments_xlsx for ./Data/SEBRA-09042026.xlsx
# INFO:etl:parsing SEBRA-09042026.xlsx
# INFO:etl:[summary section] Skipping column header row in summary, row=['Код', 'Описание', nan, 'Сума']
# INFO:etl:[summary section] Skipping descriptive row in summary: I. ПЛАЩАНИЯ ОТ БЮДЖЕТА, ИЗВЪРШЕНИ ЧРЕЗ СЕБРА, ПО ПЪРВОСТЕПЕННИ СИСТЕМИ, row=['I. ПЛАЩАНИЯ ОТ БЮДЖЕТА, ИЗВЪРШЕНИ ЧРЕЗ СЕБРА, ПО ПЪРВОСТЕПЕННИ СИСТЕМИ', nan, nan, nan]
# INFO:etl:[org section] Skipping descriptive row between sections: ПЛАЩАНИЯ ОТ БЮДЖЕТА, ИЗВЪРШЕНИ ЧРЕЗ СЕБРА, ПО ПЪРВОСТЕПЕННИ СИСТЕМИ, row=['ПЛАЩАНИЯ ОТ БЮДЖЕТА, ИЗВЪРШЕНИ ЧРЕЗ СЕБРА, ПО ПЪРВОСТЕПЕННИ СИСТЕМИ', nan, nan, nan]
# INFO:etl:[org section] Skipping column header row in org section, row=['Код', 'Описание', nan, 'Сума']
# INFO:etl:[org section] Skipping column header row in org section, row=['Код', 'Описание', nan, 'Сума']
# INFO:etl:[org section] Skipping column header row in org section, row=['Код', 'Описание', nan, 'Сума']
# ...

# %%
merged = sebra_datas[3].merged_org_data()
list(merged['organization_name'].unique())
# Out:
# ['Народно събрание',
#  'Администрацията на президента',
#  'Министерски съвет',
#  'Конституционен съд',
#  'Сметна палата',
#  'Висш съдебен съвет',
#  'Министерство на финансите',
#  'Министерство на външните работи',
#  'Министерство на отбраната',
#  'Министерство на вътрешните работи',
#  'Министерство на правосъдието',
#  'Министерство на труда и социалната политика',
#  'Министерство на здравеопазването',
#  'Министерство на образованието и науката',
#  'Министерство на културата',
#  'Министерство на околната среда и водите',
#  'Министерство на икономиката и индустрията',
#  'Министерство на регионалното развитие и благоустройството',
#  'Министерство на земеделието и храните',
#  'Министерство на транспорта и съобщенията',
#  'Министерство на енергетиката',
#  'Министерство на младежта и спорта',
#  'Комисия за разкриване на документите и за обявяване на принадлежност на български граждани към Държавна сигурност и разузнавaтелните служби на Българската народна армия',
# ...
