# %% [markdown]
# # Parser for the Excel files in folder SEBRA
#
# Currently the parser works only for years 2019, 2020, and 2021.
#
# TODO:
# - Make the parser work for years before 2019
# - Need to manually fix problems with about 5% of Excel files from before 2019 which will break the parsing code (a human needs to do that).

# %%
import pandas as pd
import numpy as np
import os

# %%
def parse_sebra_excel_file_to_pandas(excel_file_path):
    def find_organizations_start_row(df):
        org_start_phrases = [
            'ПЛАЩАНИЯ ПО ПЪРВОСТЕПЕННИ СИСТЕМИ В СЕБРА ',
            'ПЛАЩАНИЯ ОТ БЮДЖЕТА, ИЗВЪРШЕНИ ЧРЕЗ СЕБРА, ПО ПЪРВОСТЕПЕННИ СИСТЕМИ'
        ]
        correct = False
        for t in org_start_phrases:
            mask = df.iloc[:, 0] == t
            if mask.sum() == 1:
                correct = True
                break
        assert correct, f'There should be exactly one row containing any of the phrases {org_start_phrases}. File "{excel_file_path}".'
        return mask[mask].index[0]
    
    def find_operations_blocks(df, org_start_row):
        op_start_text = 'Описание'
        op_end_text = 'Общо:'
        mask_start = df.iloc[:, 1] == op_start_text
        mask_end = df.iloc[:, 0].str.startswith(op_end_text).fillna(False)
        op_start_index = mask_start[mask_start].index
        op_end_index = mask_end[mask_end].index
        
        if not (len(op_start_index) == len(op_end_index)):
            print(op_start_index, op_end_index)
            display(df)
            
        assert len(op_start_index) == len(op_end_index), f'The number of occurances of "{op_start_text}" is not the same as the number of occurances of "{op_end_text}". File "{excel_file_path}".'
        op_blocks = list(zip(op_start_index, op_end_index))
        op_blocks_dict = {
            'general': [],
            'organizations': []
        }
        for i in range(len(op_blocks)):
            b_start, b_end = op_blocks[i]
            assert b_start < b_end, f'Block start index ({b_start}) should be smaller that the end index ({b_end}). File "{excel_file_path}".'
            if i > 0:
                _, prev_b_end = op_blocks[i - 1]
                assert prev_b_end < b_start, f'Block end index ({prev_b_end}) of the previous block should be smaller that the start index of the next block ({b_start}). File "{excel_file_path}".'
            assert not (b_start < org_start_row and org_start_row < b_end), 'The starting row for organizations shouldn\'t be within an operations block. File "{excel_file_path}".'

            if b_end < org_start_row:
                op_blocks_dict['general'].append((b_start, b_end))
            else:
                op_blocks_dict['organizations'].append((b_start, b_end))

            assert len(op_blocks_dict['general']) == 1, 'There should be exactly one block for general totals. File "{excel_file_path}".'

        return op_blocks_dict

    def get_general_totals(df, general_op_block):
        new_columns = ['Operations Code', 'Operations Description', 'Operations Count', 'Operations Amount (BGN)']
        b_start, b_end = general_op_block
        block_df = df.iloc[b_start + 1: b_end].copy()
        block_df.columns = new_columns
        del block_df['Operations Count']

        # drop all rows that do not have amount value
        block_df = block_df[~block_df['Operations Amount (BGN)'].isna()]

        block_df['Operations Amount (BGN)'] = block_df['Operations Amount (BGN)'] \
            .astype(str) \
            .str.replace(' ', '') \
            .str.replace(',', '.') \
            .astype('float64')
        block_df = block_df.set_index('Operations Code')

        # check if sums are correct
        sum_row = df.iloc[b_end, :]
        sum_row.index = new_columns
        if isinstance(sum_row['Operations Amount (BGN)'], str):
            sum_row['Operations Amount (BGN)'] = float(
                sum_row['Operations Amount (BGN)'] \
                    .replace(' ', '') \
                    .replace(',', '.')
            )
        if not round(sum_row['Operations Amount (BGN)'], 2) == round(block_df['Operations Amount (BGN)'].sum(), 2):
            print(f"Warning: The sums of \"Operations Amount (BGN)\" do not match for block ({b_start}, {b_end}). Expected value \"{round(sum_row['Operations Amount (BGN)'], 2)}\". Calculated value \"{round(block_df['Operations Amount (BGN)'].sum(), 2)}\". File \"{excel_file_path}\".")

        return block_df

    def get_organization_operations_blocks(df, org_op_blocks):
        def get_organization_name_and__period(df, b_start):
            block_header = df.iloc[b_start - 1]
            org_name = block_header[0]
            if isinstance(block_header[2], str):
                # this is the standard case - the header is just one row
                period = block_header[2].split(' ')
            else:
                # this is a rare case where the header takes two rows
                block_header_1 = df.iloc[b_start - 2]
                # concat the organization name along the two rows
                assert isinstance(block_header_1[0], str), f'The first column does not contain the organization name around row {b_start} in file "{excel_file_path}".'
                org_name = block_header_1[0] + ' ' + org_name
                assert isinstance(block_header_1[2], str), f'The third column does not contain the period string around row {b_start} in file "{excel_file_path}".'
                period = block_header_1[2].split(' ')
            assert period[0] == 'Период:', f'Field for time period should start with string "Период". File "{excel_file_path}".'
            start_date = period[1]
            end_date = period[3]
            return org_name, start_date, end_date
    
        new_columns = ['Operations Code', 'Operations Description', 'Operations Count', 'Operations Amount (BGN)']
        org_op_blocks_dfs = []
        for b_start, b_end in org_op_blocks:
            org_df = df.iloc[b_start + 1: b_end, :].copy()
            assert not org_df.iloc[:, 1].isna().any(), f'There are empty cells within the operations block between rows ({b_start}, {b_end}). File "{excel_file_path}".'
            org_df.columns = new_columns
            del org_df['Operations Count']
            org_df['Operations Amount (BGN)'] = org_df['Operations Amount (BGN)'] \
                .astype(str) \
                .str.replace(' ', '') \
                .str.replace(',', '.') \
                .astype('float64')

            # get organization name and time period
            org_name, start_date, end_date = get_organization_name_and__period(df, b_start)
            org_df['Organization Name'] = org_name
            org_df['Start Date'] = start_date
            org_df['End Date'] = end_date

            # check if sums are correct
            sum_row = df.iloc[b_end, :]
            sum_row.index = new_columns
            if isinstance(sum_row['Operations Amount (BGN)'], str):
                sum_row['Operations Amount (BGN)'] = float(
                    sum_row['Operations Amount (BGN)'] \
                        .replace(' ', '') \
                        .replace(',', '.')
                )
            if not round(sum_row['Operations Amount (BGN)'], 2) == round(org_df['Operations Amount (BGN)'].sum(), 2):
                print(f"Warning: The sums of \"Operations Amount (BGN)\" do not match for block ({b_start}, {b_end}). Expected value \"{round(sum_row['Operations Amount (BGN)'], 2)}\". Calculated value \"{round(org_df['Operations Amount (BGN)'].sum(), 2)}\". File \"{excel_file_path}\".")

            org_op_blocks_dfs.append(org_df)
        return pd.concat(org_op_blocks_dfs).reset_index().drop(columns=['index'])

    def check_sums(ops_df, general_block_df):
        ops_totals_df = ops_df.groupby('Operations Code').sum()
        
        assert (ops_df['Operations Code'].dtypes == object) and (general_block_df.reset_index()['Operations Code'].dtypes == object), f'There are missing operation codes in file "{excel_file_path}".'
        
        sum_check_df = pd.merge(
            ops_totals_df,
            general_block_df,
            how='left',
            left_on='Operations Code',
            right_index=True
        )
        if not (sum_check_df['Operations Amount (BGN)_x'].round(2) == sum_check_df['Operations Amount (BGN)_y'].round(2)).all():
            print(f'Warning: Some sums do not match Operations Amount (BGN). File "{excel_file_path}".')
    
    # load Excel file to Pandas
    df = pd.read_excel(excel_file_path)
    
    # get the row that indicates the start of the organizations section
    org_start_row = find_organizations_start_row(df)
    
    # get the start and end rows for all blocks of operations
    op_blocks = find_operations_blocks(df, org_start_row)
    
    # parse the data containing the general totals for all operations in the file
    # (we will use those just to check the sums at the end for correctness)
    general_block_df = get_general_totals(df, op_blocks['general'][0])
    
    # parse all operations by organization in the file
    ops_df = get_organization_operations_blocks(df, op_blocks['organizations'])
    
    # check if the sums for all opearions by organization match the general totals
    check_sums(ops_df, general_block_df)

    # extract the Organization ID from the Name
    ops_df['Organization ID'] = ops_df['Organization Name'].str.findall(r'\((.*?)\)').map(
        lambda x: x[-1].strip() if len(x) > 0 else np.nan
    )
    
    return ops_df

# %%
def get_all_excel_files(data_dir):
    folders = [f for f in os.listdir(data_dir) if os.path.isdir(os.path.join(data_dir, f))]
    excel_files = []
    for fold in folders:
        if int(fold) < 2019:
            continue
        excel_files += [
            os.path.join(data_dir, fold, f) \
                for f in os.listdir(os.path.join(data_dir, fold)) \
                    if os.path.isfile(os.path.join(data_dir, fold, f)) \
                        and (f.endswith('.xlsx') or f.endswith('.xls'))
        ]
    return sorted(excel_files)

# %%
data_dir = './Data/Archive_10052021/SEBRA'
excel_files = get_all_excel_files(data_dir)

# %%
# test_df = parse_sebra_excel_file_to_pandas(os.path.join(data_dir, '2021', 'SEBRA-04032021.xls'))
# test_df

# %%
dfs = []
for i, f in enumerate(excel_files):
    print(i, f)
    temp_df = parse_sebra_excel_file_to_pandas(f)
    dfs.append(temp_df)
df = pd.concat(dfs)
# Out:
# 0 ./Data/Archive_10052021/SEBRA/2019/SEBRA-01022019.xls
# 1 ./Data/Archive_10052021/SEBRA/2019/SEBRA-01032019.xls
# 2 ./Data/Archive_10052021/SEBRA/2019/SEBRA-01042019.xls
# 3 ./Data/Archive_10052021/SEBRA/2019/SEBRA-01072019.xls
# 4 ./Data/Archive_10052021/SEBRA/2019/SEBRA-01082019.xls
# 5 ./Data/Archive_10052021/SEBRA/2019/SEBRA-01102019.xls
# 6 ./Data/Archive_10052021/SEBRA/2019/SEBRA-01112019.xls
# 7 ./Data/Archive_10052021/SEBRA/2019/SEBRA-02012019.xls
# 8 ./Data/Archive_10052021/SEBRA/2019/SEBRA-02042019.xls
# 9 ./Data/Archive_10052021/SEBRA/2019/SEBRA-02052019.xls
# 10 ./Data/Archive_10052021/SEBRA/2019/SEBRA-02072019.xls
# 11 ./Data/Archive_10052021/SEBRA/2019/SEBRA-02082019.xls
# Warning: Some sums do not match Operations Amount (BGN). File "./Data/Archive_10052021/SEBRA/2019/SEBRA-02082019.xls".
# 12 ./Data/Archive_10052021/SEBRA/2019/SEBRA-02092019.xls
# 13 ./Data/Archive_10052021/SEBRA/2019/SEBRA-02102019.xls
# 14 ./Data/Archive_10052021/SEBRA/2019/SEBRA-02122019.xls
# 15 ./Data/Archive_10052021/SEBRA/2019/SEBRA-03012019.xls
# 16 ./Data/Archive_10052021/SEBRA/2019/SEBRA-03042019.xls
# 17 ./Data/Archive_10052021/SEBRA/2019/SEBRA-03052019.xls
# 18 ./Data/Archive_10052021/SEBRA/2019/SEBRA-03062019.xls
# Warning: Some sums do not match Operations Amount (BGN). File "./Data/Archive_10052021/SEBRA/2019/SEBRA-03062019.xls".
# 19 ./Data/Archive_10052021/SEBRA/2019/SEBRA-03072019.xls
# 20 ./Data/Archive_10052021/SEBRA/2019/SEBRA-03092019.xls
# 21 ./Data/Archive_10052021/SEBRA/2019/SEBRA-03102019.xls
# Warning: The sums of "Operations Amount (BGN)" do not match for block (411, 413). Expected value "1907060.88". Calculated value "1905961.88". File "./Data/Archive_10052021/SEBRA/2019/SEBRA-03102019.xls".
# Warning: Some sums do not match Operations Amount (BGN). File "./Data/Archive_10052021/SEBRA/2019/SEBRA-03102019.xls".
# 22 ./Data/Archive_10052021/SEBRA/2019/SEBRA-03122019.xls
# Warning: Some sums do not match Operations Amount (BGN). File "./Data/Archive_10052021/SEBRA/2019/SEBRA-03122019.xls".
# 23 ./Data/Archive_10052021/SEBRA/2019/SEBRA-04012019.xls
# 24 ./Data/Archive_10052021/SEBRA/2019/SEBRA-04022019.xls
# 25 ./Data/Archive_10052021/SEBRA/2019/SEBRA-04042019.xls
# 26 ./Data/Archive_10052021/SEBRA/2019/SEBRA-04062019.xls
# 27 ./Data/Archive_10052021/SEBRA/2019/SEBRA-04072019.xls
# 28 ./Data/Archive_10052021/SEBRA/2019/SEBRA-04092019.xls
# 29 ./Data/Archive_10052021/SEBRA/2019/SEBRA-04102019.xls
# 30 ./Data/Archive_10052021/SEBRA/2019/SEBRA-04112019.xls
# Warning: Some sums do not match Operations Amount (BGN). File "./Data/Archive_10052021/SEBRA/2019/SEBRA-04112019.xls".
# 31 ./Data/Archive_10052021/SEBRA/2019/SEBRA-04122019.xls
# Warning: Some sums do not match Operations Amount (BGN). File "./Data/Archive_10052021/SEBRA/2019/SEBRA-04122019.xls".
# 32 ./Data/Archive_10052021/SEBRA/2019/SEBRA-05022019.xls
# 33 ./Data/Archive_10052021/SEBRA/2019/SEBRA-05032019.xls
# 34 ./Data/Archive_10052021/SEBRA/2019/SEBRA-05042019.xls
# 35 ./Data/Archive_10052021/SEBRA/2019/SEBRA-05062019.xls
# 36 ./Data/Archive_10052021/SEBRA/2019/SEBRA-05072019.xls
# 37 ./Data/Archive_10052021/SEBRA/2019/SEBRA-05082019.xls
# Warning: Some sums do not match Operations Amount (BGN). File "./Data/Archive_10052021/SEBRA/2019/SEBRA-05082019.xls".
# 38 ./Data/Archive_10052021/SEBRA/2019/SEBRA-05092019.xls
# 39 ./Data/Archive_10052021/SEBRA/2019/SEBRA-05112019.xls
# Warning: The sums of "Operations Amount (BGN)" do not match for block (420, 422). Expected value "612400.28". Calculated value "612280.28". File "./Data/Archive_10052021/SEBRA/2019/SEBRA-05112019.xls".
# Warning: Some sums do not match Operations Amount (BGN). File "./Data/Archive_10052021/SEBRA/2019/SEBRA-05112019.xls".
# 40 ./Data/Archive_10052021/SEBRA/2019/SEBRA-05122019.xls
# 41 ./Data/Archive_10052021/SEBRA/2019/SEBRA-06022019.xls
# 42 ./Data/Archive_10052021/SEBRA/2019/SEBRA-06032019.xls
# Warning: Some sums do not match Operations Amount (BGN). File "./Data/Archive_10052021/SEBRA/2019/SEBRA-06032019.xls".
# 43 ./Data/Archive_10052021/SEBRA/2019/SEBRA-06062019.xls
# 44 ./Data/Archive_10052021/SEBRA/2019/SEBRA-06082019.xls
# 45 ./Data/Archive_10052021/SEBRA/2019/SEBRA-06112019.xls
# 46 ./Data/Archive_10052021/SEBRA/2019/SEBRA-06122019.xls
# 47 ./Data/Archive_10052021/SEBRA/2019/SEBRA-07012019.xls
# 48 ./Data/Archive_10052021/SEBRA/2019/SEBRA-07022019.xls
# 49 ./Data/Archive_10052021/SEBRA/2019/SEBRA-07032019.xls
# 50 ./Data/Archive_10052021/SEBRA/2019/SEBRA-07052019.xls
# Warning: Some sums do not match Operations Amount (BGN). File "./Data/Archive_10052021/SEBRA/2019/SEBRA-07052019.xls".
# 51 ./Data/Archive_10052021/SEBRA/2019/SEBRA-07062019.xls
# 52 ./Data/Archive_10052021/SEBRA/2019/SEBRA-07082019.xls
# 53 ./Data/Archive_10052021/SEBRA/2019/SEBRA-07102019.xls
# 54 ./Data/Archive_10052021/SEBRA/2019/SEBRA-07112019.xls
# 55 ./Data/Archive_10052021/SEBRA/2019/SEBRA-08012019.xls
# Warning: Some sums do not match Operations Amount (BGN). File "./Data/Archive_10052021/SEBRA/2019/SEBRA-08012019.xls".
# 56 ./Data/Archive_10052021/SEBRA/2019/SEBRA-08022019.xls
# 57 ./Data/Archive_10052021/SEBRA/2019/SEBRA-08032019.xls
# Warning: Some sums do not match Operations Amount (BGN). File "./Data/Archive_10052021/SEBRA/2019/SEBRA-08032019.xls".
# 58 ./Data/Archive_10052021/SEBRA/2019/SEBRA-08042019.xls
# 59 ./Data/Archive_10052021/SEBRA/2019/SEBRA-08052019.xls
# 60 ./Data/Archive_10052021/SEBRA/2019/SEBRA-08072019.xls
# Warning: Some sums do not match Operations Amount (BGN). File "./Data/Archive_10052021/SEBRA/2019/SEBRA-08072019.xls".
# 61 ./Data/Archive_10052021/SEBRA/2019/SEBRA-08082019.xls
# 62 ./Data/Archive_10052021/SEBRA/2019/SEBRA-08102019.xls
# 63 ./Data/Archive_10052021/SEBRA/2019/SEBRA-08112019.xls
# 64 ./Data/Archive_10052021/SEBRA/2019/SEBRA-09012019.xls
# 65 ./Data/Archive_10052021/SEBRA/2019/SEBRA-09042019.xls
# 66 ./Data/Archive_10052021/SEBRA/2019/SEBRA-09052019.xls
# 67 ./Data/Archive_10052021/SEBRA/2019/SEBRA-09072019.xls
# 68 ./Data/Archive_10052021/SEBRA/2019/SEBRA-09082019.xls
# Warning: Some sums do not match Operations Amount (BGN). File "./Data/Archive_10052021/SEBRA/2019/SEBRA-09082019.xls".
# 69 ./Data/Archive_10052021/SEBRA/2019/SEBRA-09092019.xls
# 70 ./Data/Archive_10052021/SEBRA/2019/SEBRA-09122019.xls
# 71 ./Data/Archive_10052021/SEBRA/2019/SEBRA-10012019.xls
# 72 ./Data/Archive_10052021/SEBRA/2019/SEBRA-10042019.xls
# 73 ./Data/Archive_10052021/SEBRA/2019/SEBRA-10052019.xls
# 74 ./Data/Archive_10052021/SEBRA/2019/SEBRA-10062019.xls
# Warning: Some sums do not match Operations Amount (BGN). File "./Data/Archive_10052021/SEBRA/2019/SEBRA-10062019.xls".
# 75 ./Data/Archive_10052021/SEBRA/2019/SEBRA-10072019.xls
# Warning: Some sums do not match Operations Amount (BGN). File "./Data/Archive_10052021/SEBRA/2019/SEBRA-10072019.xls".
# 76 ./Data/Archive_10052021/SEBRA/2019/SEBRA-10092019.xls
# 77 ./Data/Archive_10052021/SEBRA/2019/SEBRA-10102019.xls
# 78 ./Data/Archive_10052021/SEBRA/2019/SEBRA-10122019.xls
# 79 ./Data/Archive_10052021/SEBRA/2019/SEBRA-11012019.xls
# Warning: Some sums do not match Operations Amount (BGN). File "./Data/Archive_10052021/SEBRA/2019/SEBRA-11012019.xls".
# 80 ./Data/Archive_10052021/SEBRA/2019/SEBRA-11022019.xls
# 81 ./Data/Archive_10052021/SEBRA/2019/SEBRA-11032019.xls
# Warning: The sums of "Operations Amount (BGN)" do not match for block (517, 519). Expected value "468277.79". Calculated value "9180.72". File "./Data/Archive_10052021/SEBRA/2019/SEBRA-11032019.xls".
# 82 ./Data/Archive_10052021/SEBRA/2019/SEBRA-11042019.xls
# 83 ./Data/Archive_10052021/SEBRA/2019/SEBRA-11062019.xls
# Warning: Some sums do not match Operations Amount (BGN). File "./Data/Archive_10052021/SEBRA/2019/SEBRA-11062019.xls".
# 84 ./Data/Archive_10052021/SEBRA/2019/SEBRA-11072019.xls
# 85 ./Data/Archive_10052021/SEBRA/2019/SEBRA-11092019.xls
# 86 ./Data/Archive_10052021/SEBRA/2019/SEBRA-11102019.xls
# 87 ./Data/Archive_10052021/SEBRA/2019/SEBRA-11112019.xls
# 88 ./Data/Archive_10052021/SEBRA/2019/SEBRA-11122019.xls
# 89 ./Data/Archive_10052021/SEBRA/2019/SEBRA-12022019.xls
# 90 ./Data/Archive_10052021/SEBRA/2019/SEBRA-12032019.xls
# 91 ./Data/Archive_10052021/SEBRA/2019/SEBRA-12042019.xls
# 92 ./Data/Archive_10052021/SEBRA/2019/SEBRA-12062019.xls
# 93 ./Data/Archive_10052021/SEBRA/2019/SEBRA-12072019.xls
# 94 ./Data/Archive_10052021/SEBRA/2019/SEBRA-12082019.xls
# 95 ./Data/Archive_10052021/SEBRA/2019/SEBRA-12092019.xls
# 96 ./Data/Archive_10052021/SEBRA/2019/SEBRA-12112019.xls
# 97 ./Data/Archive_10052021/SEBRA/2019/SEBRA-12122019.xls
# 98 ./Data/Archive_10052021/SEBRA/2019/SEBRA-13022019.xls
# 99 ./Data/Archive_10052021/SEBRA/2019/SEBRA-13032019.xls
# 100 ./Data/Archive_10052021/SEBRA/2019/SEBRA-13052019.xls
# 101 ./Data/Archive_10052021/SEBRA/2019/SEBRA-13062019.xls
# 102 ./Data/Archive_10052021/SEBRA/2019/SEBRA-13082019.xls
# 103 ./Data/Archive_10052021/SEBRA/2019/SEBRA-13092019.xls
# 104 ./Data/Archive_10052021/SEBRA/2019/SEBRA-13112019.xls
# 105 ./Data/Archive_10052021/SEBRA/2019/SEBRA-13122019.xls
# Warning: The sums of "Operations Amount (BGN)" do not match for block (757, 759). Expected value "nan". Calculated value "2400000.0". File "./Data/Archive_10052021/SEBRA/2019/SEBRA
.xls
# Warning: Some sums do not match Operations Amount (BGN). File "./Data/Archive_10052021/SEBRA/2019/SEBRA-23052019.xls".
# 186 ./Data/Archive_10052021/SEBRA/2019/SEBRA-23072019.xls
# 187 ./Data/Archive_10052021/SEBRA/2019/SEBRA-23082019.xls
# 188 ./Data/Archive_10052021/SEBRA/2019/SEBRA-23122019.xls
# 189 ./Data/Archive_10052021/SEBRA/2019/SEBRA-24012019.xls
# 190 ./Data/Archive_10052021/SEBRA/2019/SEBRA-24042019.xls
# 191 ./Data/Archive_10052021/SEBRA/2019/SEBRA-24062019.xls
# 192 ./Data/Archive_10052021/SEBRA/2019/SEBRA-24072019.xls
# 193 ./Data/Archive_10052021/SEBRA/2019/SEBRA-24092019.xls
# Warning: Some sums do not match Operations Amount (BGN). File "./Data/Archive_10052021/SEBRA/2019/SEBRA-24092019.xls".
# 194 ./Data/Archive_10052021/SEBRA/2019/SEBRA-24102019.xls
# 195 ./Data/Archive_10052021/SEBRA/2019/SEBRA-25012019.xls
# 196 ./Data/Archive_10052021/SEBRA/2019/SEBRA-25022019.xls
# 197 ./Data/Archive_10052021/SEBRA/2019/SEBRA-25032019.xls
# 198 ./Data/Archive_10052021/SEBRA/2019/SEBRA-25042019.xls
# 199 ./Data/Archive_10052021/SEBRA/2019/SEBRA-25062019.xls
# 200 ./Data/Archive_10052021/SEBRA/2019/SEBRA-25072019.xls
# 201 ./Data/Archive_10052021/SEBRA/2019/SEBRA-25092019.xls
# 202 ./Data/Archive_10052021/SEBRA/2019/SEBRA-25102019.xls
# 203 ./Data/Archive_10052021/SEBRA/2019/SEBRA-25112019.xls
# 204 ./Data/Archive_10052021/SEBRA/2019/SEBRA-26022019.xls
# 205 ./Data/Archive_10052021/SEBRA/2019/SEBRA-26032019.xls
# 206 ./Data/Archive_10052021/SEBRA/2019/SEBRA-26062019.xls
# 207 ./Data/Archive_10052021/SEBRA/2019/SEBRA-26072019.xls
# 208 ./Data/Archive_10052021/SEBRA/2019/SEBRA-26082019.xls
# 209 ./Data/Archive_10052021/SEBRA/2019/SEBRA-26092019.xls
# 210 ./Data/Archive_10052021/SEBRA/2019/SEBRA-26112019.xls
# 211 ./Data/Archive_10052021/SEBRA/2019/SEBRA-27022019.xls
# 212 ./Data/Archive_10052021/SEBRA/2019/SEBRA-27032019.xls
# 213 ./Data/Archive_10052021/SEBRA/2019/SEBRA-27052019.xls
# 214 ./Data/Archive_10052021/SEBRA/2019/SEBRA-27062019.xls
# 215 ./Data/Archive_10052021/SEBRA/2019/SEBRA-27082019.xls
# 216 ./Data/Archive_10052021/SEBRA/2019/SEBRA-27092019.xls
# 217 ./Data/Archive_10052021/SEBRA/2019/SEBRA-27112019.xls
# 218 ./Data/Archive_10052021/SEBRA/2019/SEBRA-27122019.xls
# 219 ./Data/Archive_10052021/SEBRA/2019/SEBRA-28012019.xls
# 220 ./Data/Archive_10052021/SEBRA/2019/SEBRA-28022019.xls
# 221 ./Data/Archive_10052021/SEBRA/2019/SEBRA-28032019.xls
# 222 ./Data/Archive_10052021/SEBRA/2019/SEBRA-28052019.xls
# 223 ./Data/Archive_10052021/SEBRA/2019/SEBRA-28062019.xls
# 224 ./Data/Archive_10052021/SEBRA/2019/SEBRA-28082019.xls
# 225 ./Data/Archive_10052021/SEBRA/2019/SEBRA-28102019.xls
# 226 ./Data/Archive_10052021/SEBRA/2019/SEBRA-28112019.xls
# Warning: Some sums do not match Operations Amount (BGN). File "./Data/Archive_10052021/SEBRA/2019/SEBRA-28112019.xls".
# 227 ./Data/Archive_10052021/SEBRA/2019/SEBRA-29012019.xls
# Warning: The sums of "Operations Amount (BGN)" do not match for block (382, 384). Expected value "814701.94". Calculated value "64707.2". File "./Data/Archive_10052021/SEBRA/2019/SEBRA-29012019.xls".
# Warning: Some sums do not match Operations Amount (BGN). File "./Data/Archive_10052021/SEBRA/2019/SEBRA-29012019.xls".
# 228 ./Data/Archive_10052021/SEBRA/2019/SEBRA-29032019.xls
# 229 ./Data/Archive_10052021/SEBRA/2019/SEBRA-29052019.xls
# 230 ./Data/Archive_10052021/SEBRA/2019/SEBRA-29072019.xls
# 231 ./Data/Archive_10052021/SEBRA/2019/SEBRA-29082019.xls
# 232 ./Data/Archive_10052021/SEBRA/2019/SEBRA-29102019.xls
# Warning: The sums of "Operations Amount (BGN)" do not match for block (433, 435). Expected value "314073.45". Calculated value "750.0". File "./Data/Archive_10052021/SEBRA/2019/SEBRA-29102019.xls".
# Warning: Some sums do not match Operations Amount (BGN). File "./Data/Archive_10052021/SEBRA/2019/SEBRA-29102019.xls".
# 233 ./Data/Archive_10052021/SEBRA/2019/SEBRA-29112019.xls
# Warning: The sums of "Operations Amount (BGN)" do not match for block (682, 684). Expected value "130". Calculated value "8285.55". File "./Data/Archive_10052021/SEBRA/2019/SEBRA-29112019.xls".
# Warning: Some sums do not match Operations Amount (BGN). File "./Data/Archive_10052021/SEBRA/2019/SEBRA-29112019.xls".
# 234 ./Data/Archive_10052021/SEBRA/2019/SEBRA-30012019.xls
# 235 ./Data/Archive_10052021/SEBRA/2019/SEBRA-30042019.xls
# 236 ./Data/Archive_10052021/SEBRA/2019/SEBRA-30052019.xls
# 237 ./Data/Archive_10052021/SEBRA/2019/SEBRA-30072019.xls
# 238 ./Data/Archive_10052021/SEBRA/2019/SEBRA-30082019.xls
# 239 ./Data/Archive_10052021/SEBRA/2019/SEBRA-30092019.xls
# 240 ./Data/Archive_10052021/SEBRA/2019/SEBRA-30102019.xls
# 241 ./Data/Archive_10052021/SEBRA/2019/SEBRA-30122019.xls
# 242 ./Data/Archive_10052021/SEBRA/2019/SEBRA-31012019.xls
# Warning: Some sums do not match Operations Amount (BGN). File "./Data/Archive_10052021/SEBRA/2019/SEBRA-31012019.xls".
# 243 ./Data/Archive_10052021/SEBRA/2019/SEBRA-31052019.xls
# 244 ./Data/Archive_10052021/SEBRA/2019/SEBRA-31072019.xls
# Warning: Some sums do not match Operations Amount (BGN). File "./Data/Archive_10052021/SEBRA/2019/SEBRA-31072019.xls".
# 245 ./Data/Archive_10052021/SEBRA/2019/SEBRA-31102019.xls
# 246 ./Data/Archive_10052021/SEBRA/2019/SEBRA-31122019.xls
# Warning: Some sums do not match Operations Amount (BGN). File "./Data/Archive_10052021/SEBRA/2019/SEBRA-31122019.xls".
# 247 ./Data/Archive_10052021/SEBRA/2019/SEBRAMC-09102019.xls
# 248 ./Data/Archive_10052021/SEBRA/2020/SEBRA-01042020.xls
# 249 ./Data/Archive_10052021/SEBRA/2020/SEBRA-01062020.xls
# 250 ./Data/Archive_10052021/SEBRA/2020/SEBRA-01072020.xls
# 251 ./Data/Archive_10052021/SEBRA/2020/SEBRA-01092020.xls
# 252 ./Data/Archive_10052021/SEBRA/2020/SEBRA-01102020.xls
# 253 ./Data/Archive_10052021/SEBRA/2020/SEBRA-01122020.xls
# 254 ./Data/Archive_10052021/SEBRA/2020/SEBRA-02012020.xls
# 255 ./Data/Archive_10052021/SEBRA/2020/SEBRA-02032020.xls
# 256 ./Data/Archive_10052021/SEBRA/2020/SEBRA-02042020.xls
# 257 ./Data/Archive_10052021/SEBRA/2020/SEBRA-02062020.xls
# 258 ./Data/Archive_10052021/SEBRA/2020/SEBRA-02072020.xls
# 259 ./Data/Archive_10052021/SEBRA/2020/SEBRA-02092020.xls
# 260 ./Data/Archive_10052021/SEBRA/2020/SEBRA-02102020.xls
# 261 ./Data/Archive_10052021/SEBRA/2020/SEBRA-02112020.xls
# 262 ./Data/Archive_10052021/SEBRA/2020/SEBRA-02122020.xls
# 263 ./Data/Archive_10052021/SEBRA/2020/SEBRA-03012020.xls
# Warning: Some sums do not match Operations Amount (BGN). File "./Data/Archive_10052021/SEBRA/2020/SEBRA-03012020.xls".
# 264 ./Data/Archive_10052021/SEBRA/2020/SEBRA-03022020.xls
# 265 ./Data/Archive_10052021/SEBRA/2020/SEBRA-03042020.xls
# 266 ./Data/Archive_10052021/SEBRA/2020/SEBRA-03062020.xls
# 267 ./Data/Archive_10052021/SEBRA/2020/SEBRA-03072020.xls
# 268 ./Data/Archive_10052021/SEBRA/2020/SEBRA-03082020.xls
# 269 ./Data/Archive_10052021/SEBRA/2020/SEBRA-03092020.xls
# 270 ./Data/Archive_10052021/SEBRA/2020/SEBRA-03112020.xls
# 271 ./Data/Archive_10052021/SEBRA/2020/SEBRA-03122020.xls
# Warning: Some sums do not match Operations Amount (BGN). File "./Data/Archive_10052021/SEBRA/2020/SEBRA-03122020.xls".
# 272 ./Data/Archive_10052021/SEBRA/2020/SEBRA-04022020.xls
# 273 ./Data/Archive_10052021/SEBRA/2020/SEBRA-04032020.xls
# 274 ./Data/Archive_10052021/SEBRA/2020/SEBRA-04052020.xls
# 275 ./Data/Archive_10052021/SEBRA/2020/SEBRA-04062020.xls
# 276 ./Data/Archive_10052021/SEBRA/2020/SEBRA-04082020.xls
# 277 ./Data/Archive_10052021/SEBRA/2020/SEBRA-04092020.xls
# 278 ./Data/Archive_10052021/SEBRA/2020/SEBRA-04112020.xls
# 279 ./Data/Archive_10052021/SEBRA/2020/SEBRA-04122020.xls
# 280 ./Data/Archive_10052021/SEBRA/2020/SEBRA-05022020.xls
# 281 ./Data/Archive_10052021/SEBRA/2020/SEBRA-05032020.xls
# 282 ./Data/Archive_10052021/SEBRA/2020/SEBRA-05052020.xls
# Warning: Some sums do not match Operations Amount (BGN). File "./Data/Archive_10052021/SEBRA/2020/SEBRA-05052020.xls".
# 283 ./Data/Archive_10052021/SEBRA/2020/SEBRA-05062020.xls
# 284 ./Data/Archive_10052021/SEBRA/2020/SEBRA-05082020.xls
# 285 ./Data/Archive_10052021/SEBRA/2020/SEBRA-05102020.xls
# 286 ./Data/Archive_10052021/SEBRA/2020/SEBRA-05112020.xls
# 287 ./Data/Archive_10052021/SEBRA/2020/SEBRA-06022020.xls
# 288 ./Data/Archive_10052021/SEBRA/2020/SEBRA-06032020.xls
# 289 ./Data/Archive_10052021/SEBRA/2020/SEBRA-06042020.xls
# Warning: Some sums do not match Operations Amount (BGN). File "./Data/Archive_10052021/SEBRA/2020/SEBRA-06042020.xls".
# 290 ./Data/Archive_10052021/SEBRA/2020/SEBRA-06072020.xls
# 291 ./Data/Archive_10052021/SEBRA/2020/SEBRA-06082020.xls
# 292 ./Data/Archive_10052021/SEBRA/2020/SEBRA-06102020.xls
# Warning: Some sums do not match Operations Amount (BGN). File "./Data/Archive_10052021/SEBRA/2020/SEBRA-06102020.xls".
# 293 ./Data/Archive_10052021/SEBRA/2020/SEBRA-06112020.xls
# 294 ./Data/Archive_10052021/SEBRA/2020/SEBRA-07012020.xls
# 295 ./Data/Archive_10052021/SEBRA/2020/SEBRA-07022020.xls
# 296 ./Data/Archive_10052021/SEBRA/2020/SEBRA-07042020.xls
# 297 ./Data/Archive_10052021/SEBRA/2020/SEBRA-07052020.xls
# Warning: Some sums do not match Operations Amount (BGN). File "./Data/Archive_10052021/SEBRA/2020/SEBRA-07052020.xls".
# 298 ./Data/Archive_10052021/SEBRA/2020/SEBRA-07072020.xls
# Warning: Some sums do not match Operations Amount (BGN). File "./Data/Archive_10052021/SEBRA/2020/SEBRA-07072020.xls".
# 299 ./Data/Archive_10052021/SEBRA/2020/SEBRA-07082020.xls
# 300 ./Data/Archive_10052021/SEBRA/2020/SEBRA-07102020.xls
# 301 ./Data/Archive_10052021/SEBRA/2020/SEBRA-07122020.xls
# 302 ./Data/Archive_10052021/SEBRA/2020/SEBRA-08012020.xls
# 303 ./Data/Archive_10052021/SEBRA/2020/SEBRA-08042020.xls
# 304 ./Data/Archive_10052021/SEBRA/2020/SEBRA-08052020.xls
# 305 ./Data/Archive_10052021/SEBRA/2020/SEBRA-08062020.xls
# Warning: Some sums do not match Operations Amount (BGN). File "./Data/Archive_10052021/SEBRA/2020/SEBRA-08062020.xls".
# 306 ./Data/Archive_10052021/SEBRA/2020/SEBRA-08072020.xls
# Warning: Some sums do not match Operations Amount (BGN). File "./Data/Archive_10052021/SEBRA/2020/SEBRA-08072020.xls".
# 307 ./Data/Archive_10052021/SEBRA/2020/SEBRA-08092020.xls
# 308 ./Data/Archive_10052021/SEBRA/2020/SEBRA-08102020.xls
# 309 ./Data/Archive_10052021/SEBRA/2020/SEBRA-08122020.xls
# 310 ./Data/Archive_10052021/SEBRA/2020/SEBRA-09012020.xls
# 311 ./Data/Archive_10052021/SEBRA/2020/SEBRA-09032020.xls
# 312 ./Data/Archive_10052021/SEBRA/2020/SEBRA-09042020.xls
# 313 ./Data/Archive_10052021/SEBRA/2020/SEBRA-09062020.xls
# 314 ./Data/Archive_10052021/SEBRA/2020/SEBRA-09072020.xls
# 315 ./Data/Archive_10052021/SEBRA/2020/SEBRA-09092020.xls
# Warning: Some sums do not match Operations Amount (BGN). File "./Data/Archive_10052021/SEBRA/2020/SEBRA-09092020.xls".
# 316 ./Data/Archive_10052021/SEBRA/2020/SEBRA-09102020.xls
# 317 ./Data/Archive_10052021/SEBRA/2020/SEBRA-09112020.xls
# 318 ./Data/Archive_10052021/SEBRA/2020/SEBRA-09122020.xls
# 319 ./Data/Archive_10052021/SEBRA/2020/SEBRA-10012020.xls
# 320 ./Data/Archive_10052021/SEBRA/2020/SEBRA-10022020.xls
# 321 ./Data/Archive_10052021/SEBRA/2020/SEBRA-10032020.xls
# 322 ./Data/Archive_10052021/SEBRA/2020/SEBRA-10042020.xls
# 323 ./Data/Archive_10052021/SEBRA/2020/SEBRA-10062020.xls
# Warning: Some sums do not match Operations Amount (BGN). File "./Data/Archive_10052021/SEBRA/2020/SEBRA-10062020.xls".
# 324 ./Data/Archive_10052021/SEBRA/2020/SEBRA-10072020.xls
# 325 ./Data/Archive_10052021/SEBRA/2020/SEBRA-10082020.xls
# Warning: The sums of "Operations Amount (BGN)" do not match for block (107, 117). Expected value "2654781.64". Calculated value "2487760.94". File "./Data/Archive_10052021/SEBRA/2020/SEBRA-10082020.xls".
# Warning: Some sums do not match Operations Amount (BGN). File "./Data/Archive_10052021/SEBRA/2020/SEBRA-10082020.xls".
# 326 ./Data/Archive_10052021/SEBRA/2020/SEBRA-10092020.xls
# 327 ./Data/Archive_10052021/SEBRA/2020/SEBRA-10112020.xls
# 328 ./Data/Archive_10052021/SEBRA/2020/SEBRA-10122020.xls
# 329 ./Data/Archive_10052021/SEBRA/2020/SEBRA-11022020.xls
# 330 ./Data/Archive_10052021/SEBRA/2020/SEBRA-11032020.xls
# 331 ./Data/Archive_10052021/SEBRA/2020/SEBRA-11052020.xls
# 332 ./Data/Archive_10052021/SEBRA/2020/SEBRA-11062020.xls
# 333 ./Data/Archive_10052021/SEBRA/2020/SEBRA-11082020.xls
# 334 ./Data/Archive_10052021/SEBRA/2020/SEBRA-11092020.xls
# 335 ./Data/Archive_10052021/SEBRA/2020/SEBRA-11112020.xls
# 336 ./Data/Archive_10052021/SEBRA/2020/SEBRA-11122020.xls
# 337 ./Data/Archive_10052021/SEBRA/2020/SEBRA-12022020.xls
# 338 ./Data/Archive_10052021/SEBRA/2020/SEBRA-12032020.xls
# 339 ./Data/Archive_10052021/SEBRA/2020/SEBRA-12052020.xls
# 340 ./Data/Archive_10052021/SEBRA/2020/SEBRA-12062020.xls
# 341 ./Data/Archive_10052021/SEBRA/2020/SEBRA-12082020.xls
# 342 ./Data/Archive_10052021/SEBRA/2020/SEBRA-12102020.xls
# 343 ./Data/Archive_10052021/SEBRA/2020/SEBRA-12112020.xls
# 344 ./Data/Archive_10052021/SEBRA/2020/SEBRA-13012020.xls
# Warning: Some sums do not match Operations Amount (BGN). File "./Data/Archive_10052021/SEBRA/2020/SEBRA-13012020.xls".
# 345 ./Data/Archive_10052021/SEBRA/2020/SEBRA-13022020.xls
# 346 ./Data/Archive_10052021/SEBRA/2020/SEBRA-13032020.xls
# Warning: Some sums do not match Operations Amount (BGN). File "./Data/Archive_10052021/SEBRA/2020/SEBRA-13032020.xls".
# 347 ./Data/Archive_10052021/SEBRA/2020/SEBRA-13042020.xls
# 348 ./Data/Archive_10052021/SEBRA/2020/SEBRA-13052020.xls
# 349 ./Data/Archive_10052021/SEBRA/2020/SEBRA-13072020.xls
# Warning: Some sums do not match Operations Amount (BGN). File "./Data/Archive_10052021/SEBRA/2020/SEBRA-13072020.xls".
# 350 ./Data/Archive_10052021/SEBRA/2020/SEBRA-13082020.xls
# Warning: Some sums do not match Operations Amount (BGN). File "./Data/Archive_10052021/SEBRA/2020/SEBRA-13082020.xls".
# 351 ./Data/Archive_10052021/SEBRA/2020/SEBRA-13102020.xls
# Warning: The sums of "Operations Amount (BGN)" do not match for block (424, 426). Expected value "1659397.41". Calculated value "61122.7". File "./Data/Archive_10052021/SEBRA/2020/SEBRA-13102020.xls".
# Warning: The sums of "Operations Amount (BGN)" do not match for block (430, 432). Expected value "644064.89". Calculated value "243111.25". File "./Data/Archive_10052021/SEBRA/2020/SEBRA-13102020.xls".
# Warning: Some sums do not match Operations Amount (BGN). File "./Data/Archive_10052021/SEBRA/2020/SEBRA-13102020.xls".
# 352 ./Data/Archive_10052021/SEBRA/2020/SEBRA-13112020.xls
# 353 ./Data/Archive_10052021/SEBRA/2020/SEBRA-14012020.xls
# 354 ./Data/Archive_10052021/SEBRA/2020/SEBRA-14022020.xls
# 355 ./Data/Archive_10052021/SEBRA/2020/SEBRA-14042020.xls
# 356 ./Data/Archive_10052021/SEBRA/2020/SEBRA-14052020.xls
# 357 ./Data/Archive_10052021/SEBRA/2020/SEBRA-14072020.xls
# 358 ./Data/Archive_10052021/SEBRA/2020/SEBRA-14082020.xls
# Warning: Some sums do not match Operations Amount (BGN). File "./Data/Archive_10052021/SEBRA/2020/SEBRA-14082020.xls".
# 359 ./Data/Archive_10052021/SEBRA/2020/SEBRA-14092020.xls
# 360 ./Data/Archive_10052021/SEBRA/2020/SEBRA-14102020.xls
# 361 ./Data/Archive_10052021/SEBRA/2020/SEBRA-14122020.xls
# 362 ./Data/Archive_10052021/SEBRA/2020/SEBRA-15012020.xls
# 363 ./Data/Archive_10052021/SEBRA/2020/SEBRA-15042020.xls
# 364 ./Data/Archive_10052021/SEBRA/2020/SEBRA-15052020.xls
# 365 ./Data/Archive_10052021/SEBRA/2020/SEBRA-15062020.xls
# 366 ./Data/Archive_10052021/SEBRA/2020/SEBRA-15072020.xls
# 367 ./Data/Archive_10052021/SEBRA/2020/SEBRA-15092020.xls
# 368 ./Data/Archive_10052021/SEBRA/2020/SEBRA-15102020.xls
# Warning: The sums of "Operations Amount (BGN)" do not match for block (366, 368). Expected value "891134.92". Calculated value "41840.0". File "./Data/Archive_10052021/SEBRA/2020/SEBRA-15102020.xls".
# Warning: Some sums do not match Operations Amount (BGN). File "./Data/Archive_10052021/SEBRA/2020/SEBRA-15102020.xls".
# 369 ./Data/Archive_10052021/SEBRA/2020/SEBRA-15122020.xls
# Warning: Some sums do not match Operations Amount (BGN). File "./Data/Archive_10052021/SEBRA/2020/SEBRA-15122020.xls".
# 370 ./Data/Archive_10052021/SEBRA/2020/SEBRA-16012020.xls
# 371 ./Data/Archive_10052021/SEBRA/2020/SEBRA-16032020.xls
# 372 ./Data/Archive_10052021/SEBRA/2020/SEBRA-16042020.xls
# 373 ./Data/Archive_10052021/SEBRA/2020/SEBRA-16062020.xls
# 374 ./Data/Archive_10052021/SEBRA/2020/SEBRA-16072020.xls
# 375 ./Data/Archive_10052021/SEBRA/2020/SEBRA-16092020.xls
# 376 ./Data/Archive_10052021/SEBRA/2020/SEBRA-16102020.xls
# 377 ./Data/Archive_10052021/SEBRA/2020/SEBRA-16112020.xls
# 378 ./Data/Archive_10052021/SEBRA/2020/SEBRA-16122020.xls
# 379 ./Data/Archive_10052021/SEBRA/2020/SEBRA-17012020.xls
# 380 ./Data/Archive_10052021/SEBRA/2020/SEBRA-17022020.xls
# 381 ./Data/Archive_10052021/SEBRA/2020/SEBRA-17032020.xls
# 382 ./Data/Archive_10052021/SEBRA/2020/SEBRA-17062020.xls
# 383 ./Data/Archive_10052021/SEBRA/2020/SEBRA-17072020.xls
# 384 ./Data/Archive_10052021/SEBRA/2020/SEBRA-17082020.xls
# 385 ./Data/Archive_10052021/SEBRA/2020/SEBRA-17092020.xls
# 386 ./Data/Archive_10052021/SEBRA/2020/SEBRA-17112020.xls
# 387 ./Data/Archive_10052021/SEBRA/2020/SEBRA-17122020.xls
# 388 ./Data/Archive_10052021/SEBRA/2020/SEBRA-18022020.xls
# 389 ./Data/Archive_10052021/SEBRA/2020/SEBRA-18032020.xls
# 390 ./Data/Archive_10052021/SEBRA/2020/SEBRA-18052020.xls
# Warning: Some sums do not match Operations Amount (BGN). File "./Data/Archive_10052021/SEBRA/2020/SEBRA-18052020.xls".
# 391 ./Data/Archive_10052021/SEBRA/2020/SEBRA-18062020.xls
# 392 ./Data/Archive_10052021/SEBRA/2020/SEBRA-18082020.xls
# 393 ./Data/Archive_10052021/SEBRA/2020/SEBRA-18092020.xls
# 394 ./Data/Archive_10052021/SEBRA/2020/SEBRA-18112020.xls
# 395 ./Data/Archive_10052021/SEBRA/2020/SEBRA-18122020.xls
# 396 ./Data/Archive_10052021/SEBRA/2020/SEBRA-19022020.xls
# 397 ./Data/Archive_10052021/SEBRA/2020/SEBRA-19032020.xls
# Warning: Some sums do not match Operations Amount (BGN). File "./Data/Archive_10052021/SEBRA/2020/SEBRA-19032020.xls".
# 398 ./Data/Archive_10052021/SEBRA/2020/SEBRA-19052020.xls
# 399 ./Data/Archive_10052021/SEBRA/2020/SEBRA-19062020.xls
# 400 ./Data/Archive_10052021/SEBRA/2020/SEBRA-19082020.xls
# Warning: Some sums do not match Operations Amount (BGN). File "./Data/Archive_10052021/SEBRA/2020/SEBRA-19082020.xls".
# 401 ./Data/Archive_10052021/SEBRA/2020/SEBRA-19102020.xls
# 402 ./Data/Archive_10052021/SEBRA/2020/SEBRA-19112020.xls
# 403 ./Data/Archive_10052021/SEBRA/2020/SEBRA-20012020.xls
# 404 ./Data/Archive_10052021/SEBRA/2020/SEBRA-20022020.xls
# Warning: Some sums do not match Operations Amount (BGN). File "./Data/Archive_10052021/SEBRA/2020/SEBRA-20022020.xls".
# 405 ./Data/Archive_10052021/SEBRA/2020/SEBRA-20032020.xls
# 406 ./Data/Archive_10052021/SEBRA/2020/SEBRA-20052020.xls
# 407 ./Data/Archive_10052021/SEBRA/2020/SEBRA-20072020.xls
# 408 ./Data/Archive_10052021/SEBRA/2020/SEBRA-20082020.xls
# 409 ./Data/Archive_10052021/SEBRA/2020/SEBRA-20102020.xls
# 410 ./Data/Archive_10052021/SEBRA/2020/SEBRA-20112020.xls
# 411 ./Data/Archive_10052021/SEBRA/2020/SEBRA-21012020.xls
# 412 ./Data/Archive_10052021/SEBRA/2020/SEBRA-21022020.xls
# 413 ./Data/Archive_10052021/SEBRA/2020/SEBRA-21042020.xls
# 414 ./Data/Archive_10052021/SEBRA/2020/SEBRA-21052020.xls
# 415 ./Data/Archive_10052021/SEBRA/2020/SEBRA-21072020.xls
# 416 ./Data/Archive_10052021/SEBRA/2020/SEBRA-21082020.xls
# 417 ./Data/Archive_10052021/SEBRA/2020/SEBRA-21092020.xls
# 418 ./Data/Archive_10052021/SEBRA/2020/SEBRA-21102020.xls
# 419 ./Data/Archive_10052021/SEBRA/2020/SEBRA-21122020.xls
# 420 ./Data/Archive_10052021/SEBRA/2020/SEBRA-22012020.xls
# Warning: Some sums do not match Operations Amount (BGN). File "./Data/Archive_10052021/SEBRA/2020/SEBRA-22012020.xls".
# 421 ./Data/Archive_10052021/SEBRA/2020/SEBRA-22042020.xls
# Warning: The sums of "Operations Amount (BGN)" do not match for block (525, 527). Expected value "189872.3". Calculated value "1294.65". File "./Data/Archive_10052021/SEBRA/2020/SEBRA-22042020.xls".
# Warning: Some sums do not match Operations Amount (BGN). File "./Data/Archive_10052021/SEBRA/2020/SEBRA-22042020.xls".
# 422 ./Data/Archive_10052021/SEBRA/2020/SEBRA-22052020.xls
# 423 ./Data/Archive_10052021/SEBRA/2020/SEBRA-22062020.xls
# 424 ./Data/Archive_10052021/SEBRA/2020/SEBRA-22072020.xls
# Warning: Some sums do not match Operations Amount (BGN). File "./Data/Archive_10052021/SEBRA/2020/SEBRA-22072020.xls".
# 425 ./Data/Archive_10052021/SEBRA/2020/SEBRA-22102020.xls
# 426 ./Data/Archive_10052021/SEBRA/2020/SEBRA-22122020.xls
# 427 ./Data/Archive_10052021/SEBRA/2020/SEBRA-23012020.xls
# 428 ./Data/Archive_10052021/SEBRA/2020/SEBRA-23032020.xls
# 429 ./Data/Archive_10052021/SEBRA/2020/SEBRA-23042020.xls
# 430 ./Data/Archive_10052021/SEBRA/2020/SEBRA-23062020.xls
# 431 ./Data/Archive_10052021/SEBRA/2020/SEBRA-23072020.xls
# 432 ./Data/Archive_10052021/SEBRA/2020/SEBRA-23092020.xls
# 433 ./Data/Archive_10052021/SEBRA/2020/SEBRA-23102020.xls
# 434 ./Data/Archive_10052021/SEBRA/2020/SEBRA-23112020.xls
# 435 ./Data/Archive_10052021/SEBRA/2020/SEBRA-23122020.xls
# 436 ./Data/Archive_10052021/SEBRA/2020/SEBRA-24012020.xls
# Warning: Some sums do not match Operations Amount (BGN). File "./Data/Archive_10052021/SEBRA/2020/SEBRA-24012020.xls".
# 437 ./Data/Archive_10052021/SEBRA/2020/SEBRA-24022020.xls
# 438 ./Data/Archive_10052021/SEBRA/2020/SEBRA-24032020.xls
# 439 ./Data/Archive_10052021/SEBRA/2020/SEBRA-24042020.xls
# 440 ./Data/Archive_10052021/SEBRA/2020/SEBRA-24062020.xls
# 441 ./Data/Archive_10052021/SEBRA/2020/SEBRA-24072020.xls
# 442 ./Data/Archive_10052021/SEBRA/2020/SEBRA-24082020.xls
# 443 ./Data/Archive_10052021/SEBRA/2020/SEBRA-24092020.xls
# 444 ./Data/Archive_10052021/SEBRA/2020/SEBRA-24112020.xls
# 445 ./Data/Archive_10052021/SEBRA/2020/SEBRA-25022020.xls
# 446 ./Data/Archive_10052021/SEBRA/2020/SEBRA-25032020.xls
# 447 ./Data/Archive_10052021/SEBRA/2020/SEBRA-25062020.xls
# Warning: Some sums do not match Operations Amount (BGN). File "./Data/Archive_10052021/SEBRA/2020/SEBRA-25062020.xls".
# 448 ./Data/Archive_10052021/SEBRA/2020/SEBRA-25082020.xls
# 449 ./Data/Archive_10052021/SEBRA/2020/SEBRA-25092020.xls
# 450 ./Data/Archive_10052021/SEBRA/2020/SEBRA-25112020.xls
# 451 ./Data/Archive_10052021/SEBRA/2020/SEBRA-26022020.xls
# 452 ./Data/Archive_10052021/SEBRA/2020/SEBRA-26032020.xls
# 453 ./Data/Archive_10052021/SEBRA/2020/SEBRA-26052020.xls
# 454 ./Data/Archive_10052021/SEBRA/2020/SEBRA-26062020.xls
# 455 ./Data/Archive_10052021/SEBRA/2020/SEBRA-26082020.xls
# 456 ./Data/Archive_10052021/SEBRA/2020/SEBRA-26102020.xls
# 457 ./Data/Archive_10052021/SEBRA/2020/SEBRA-26112020.xls
# 458 ./Data/Archive_10052021/SEBRA/2020/SEBRA-27012020.xls
# 459 ./Data/Archive_10052021/SEBRA/2020/SEBRA-27022020.xls
# 460 ./Data/Archive_10052021/SEBRA/2020/SEBRA-27032020.xls
# 461 ./Data/Archive_10052021/SEBRA/2020/SEBRA-27042020.xls
# 462 ./Data/Archive_10052021/SEBRA/2020/SEBRA-27052020.xls
# Warning: Some sums do not match Operations Amount (BGN). File "./Data/Archive_10052021/SEBRA/2020/SEBRA-27052020.xls".
# 463 ./Data/Archive_10052021/SEBRA/2020/SEBRA-27072020.xls
# 464 ./Data/Archive_10052021/SEBRA/2020/SEBRA-27082020.xls
# 465 ./Data/Archive_10052021/SEBRA/2020/SEBRA-27102020.xls
# 466 ./Data/Archive_10052021/SEBRA/2020/SEBRA-27112020.xls
# 467 ./Data/Archive_10052021/SEBRA/2020/SEBRA-28012020.xls
# 468 ./Data/Archive_10052021/SEBRA/2020/SEBRA-28022020.xls
# 469 ./Data/Archive_10052021/SEBRA/2020/SEBRA-28042020.xls
# 470 ./Data/Archive_10052021/SEBRA/2020/SEBRA-28052020.xls
# 471 ./Data/Archive_10052021/SEBRA/2020/SEBRA-28072020.xls
# 472 ./Data/Archive_10052021/SEBRA/2020/SEBRA-28082020.xls
# 473 ./Data/Archive_10052021/SEBRA/2020/SEBRA-28092020.xls
# 474 ./Data/Archive_10052021/SEBRA/2020/SEBRA-28102020.xls
# Warning: Some sums do not match Operations Amount (BGN). File "./Data/Archive_10052021/SEBRA/2020/SEBRA-28102020.xls".
# 475 ./Data/Archive_10052021/SEBRA/2020/SEBRA-29012020.xls
# 476 ./Data/Archive_10052021/SEBRA/2020/SEBRA-29042020.xls
# 477 ./Data/Archive_10052021/SEBRA/2020/SEBRA-29052020.xls
# 478 ./Data/Archive_10052021/SEBRA/2020/SEBRA-29062020.xls
# 479 ./Data/Archive_10052021/SEBRA/2020/SEBRA-29072020.xls
# 480 ./Data/Archive_10052021/SEBRA/2020/SEBRA-29092020.xls
# 481 ./Data/Archive_10052021/SEBRA/2020/SEBRA-29102020.xls
# 482 ./Data/Archive_10052021/SEBRA/2020/SEBRA-29122020.xls
# 483 ./Data/Archive_10052021/SEBRA/2020/SEBRA-30012020.xls
# 484 ./Data/Archive_10052021/SEBRA/2020/SEBRA-30032020.xls
# 485 ./Data/Archive_10052021/SEBRA/2020/SEBRA-30042020.xls
# 486 ./Data/Archive_10052021/SEBRA/2020/SEBRA-30062020.xls
# Warning: Some sums do not match Operations Amount (BGN). File "./Data/Archive_10052021/SEBRA/2020/SEBRA-30062020.xls".
# 487 ./Data/Archive_10052021/SEBRA/2020/SEBRA-30072020.xls
# 488 ./Data/Archive_10052021/SEBRA/2020/SEBRA-30092020.xls
# Warning: The sums of "Operations Amount (BGN)" do not match for block (438, 440). Expected value "2371247.12". Calculated value "3694.99". File "./Data/Archive_10052021/SEBRA/2020/SEBRA-30092020.xls".
# Warning: The sums of "Operations Amount (BGN)" do not match for block (444, 446). Expected value "1339591.19". Calculated value "904999.19". File "./Data/Archive_10052021/SEBRA/2020/SEBRA-30092020.xls".
# Warning: Some sums do not match Operations Amount (BGN). File "./Data/Archive_10052021/SEBRA/2020/SEBRA-30092020.xls".
# 489 ./Data/Archive_10052021/SEBRA/2020/SEBRA-30102020.xls
# Warning: Some sums do not match Operations Amount (BGN). File "./Data/Archive_10052021/SEBRA/2020/SEBRA-30102020.xls".
# 490 ./Data/Archive_10052021/SEBRA/2020/SEBRA-30112020.xls
# 491 ./Data/Archive_10052021/SEBRA/2020/SEBRA-30122020.xls
# 492 ./Data/Archive_10052021/SEBRA/2020/SEBRA-31012020.xls
# 493 ./Data/Archive_10052021/SEBRA/2020/SEBRA-31032020.xls
# 494 ./Data/Archive_10052021/SEBRA/2020/SEBRA-31072020.xls
# 495 ./Data/Archive_10052021/SEBRA/2020/SEBRA-31082020.xls
# 496 ./Data/Archive_10052021/SEBRA/2020/SEBRA-31122020.xls
# Warning: Some sums do not match Operations Amount (BGN). File "./Data/Archive_10052021/SEBRA/2020/SEBRA-31122020.xls".
# 497 ./Data/Archive_10052021/SEBRA/2021/SEBRA-01022021.xls
# 498 ./Data/Archive_10052021/SEBRA/2021/SEBRA-01032021.xls
# 499 ./Data/Archive_10052021/SEBRA/2021/SEBRA-01042021.xls
# 500 ./Data/Archive_10052021/SEBRA/2021/SEBRA-02022021.xls
# 501 ./Data/Archive_10052021/SEBRA/2021/SEBRA-02032021.xls
# 502 ./Data/Archive_10052021/SEBRA/2021/SEBRA-02042021.xls
# 503 ./Data/Archive_10052021/SEBRA/2021/SEBRA-03022021.xls
# 504 ./Data/Archive_10052021/SEBRA/2021/SEBRA-04012021.xls
